# %% [markdown]
# # <a href="https://www.givingback.ai" target="_blank"><img src="https://givingback.ai/assets/gblogo.72c0863b.svg"  align="center" height="48" width="48" style="background-color: black;"></a>  GivingbackAI Education - How to use OpenSourceNepal (OSN) API

# %% [markdown]
# - YouTube Link: [https://youtu.be/U_-QPosdlPk](https://youtu.be/U_-QPosdlPk)
# - OpenSourceNepal API: [https://www.opensourcenepal.com/](https://www.opensourcenepal.com/)

# %%
import requests
import pandas as pd

# %%
url = "https://www.opensourcenepal.com/imports"

# set params
params = {
    "limit": 200,
    "offset": 0
}

response = requests.get(url,params=params)

# check if the requests was successful (status code 200)
if response.status_code == 200:
    # extract the data from the response
    data = response.json()
    # print the data 
    print(data)
    print(type(data))
else:
    print("Error: Failed to retrieve data from the API.")
# Out:
# [{'code': '40030000', 'parent_category': '40', 'commodity': 'Reclaimed rubber in primary form', 'imported_from': 'China', 'unit': 'Kg.', 'qt': 16721.0, 'amount': 2373262.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40040000', 'parent_category': '40', 'commodity': 'Waste and scrap of rubber', 'imported_from': 'China', 'unit': 'Kg.', 'qt': 28501.0, 'amount': 2077227.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40040000', 'parent_category': '40', 'commodity': 'Waste and scrap of rubber', 'imported_from': 'India', 'unit': 'Kg.', 'qt': 31094.0, 'amount': 1360511.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40051000', 'parent_category': '40', 'commodity': 'Rubber compounded wih carbon black or silica', 'imported_from': 'India', 'unit': 'Kg.', 'qt': 28266.0, 'amount': 5425026.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40052000', 'parent_category': '40', 'commodity': 'Solution, disperision of compounded rubber', 'imported_from': 'India', 'unit': 'Kg.', 'qt': 3870.0, 'amount': 593212.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40052000', 'parent_category': '40', 'commodity': 'Solution, disperision of compounded rubber', 'imported_from': 'China', 'unit': 'Kg.', 'qt': 200.0, 'amount': 21852.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40059100', 'parent_category': '40', 'commodity': 'Compounded rubber, unvulcanised in plates, sheets and strip', 'imported_from': 'India', 'unit': 'Kg.', 'qt': 204763.0, 'amount': 39309555.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40151900', 'parent_category': '40', 'commodity': 'Rubber gloves', 'imported_from': 'China', 'unit': 'Pcs.', 'qt': 839088.0, 'amount': 9997928.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40059100', 'parent_category': '40', 'commodity': 'Compounded rubber, unvulcanised in plates, sheets and strip', 'imported_from': 'United Kingdom', 'unit': 'Kg.', 'qt': 280.0, 'amount': 446643.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40059100', 'parent_category': '40', 'commodity': 'Compounded rubber, unvulcanised in plates, sheets and strip', 'imported_from': 'China', 'unit': 'Kg.', 'qt': 1723.0, 'amount': 160000.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40059100', 'parent_category': '40', 'commodity': 'Compounded rubber, unvulcanised in plates, sheets and strip', 'imported_from': 'Thailand', 'unit': 'Kg.', 'qt': 120.0, 'amount': 98717.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40059900', 'parent_category': '40', 'commodity': 'Compounded rubber', 'imported_from': 'India', 'unit': 'Kg.', 'qt': 39800.0, 'amount': 6935176.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40061000', 'parent_category': '40', 'commodity': 'Camel back strips for retreading rubber  tyres', 'imported_from': 'United Kingdom', 'unit': 'Kg.', 'qt': 10.0, 'amount': 55151.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40061000', 'parent_category': '40', 'commodity': 'Camel back strips for retreading rubber  tyres', 'imported_from': 'India', 'unit': 'Kg.', 'qt': 58.0, 'amount': 14516.0, 'currency': 'NPR', 'year': '2071/2072', 'data_source': 'https://nepaltradeportal.gov.np/'}, {'code': '40061000', 'parent_category': '40', 'commodity': 'Camel back strips for retreading rubber  tyres', 'imported_from': 'China', 'unit': 'Kg.', 'qt': 50.0, 'amount': 10263.0, 'c ...
# <class 'list'>

# %%
##  get the column names fromt the first row of data
my_columns = data[0]
my_columns
type(my_columns)
# Out:
# dict

# %%
# extract columns from keys
my_columns = my_columns.keys()
my_columns
# Out:
# dict_keys(['code', 'parent_category', 'commodity', 'imported_from', 'unit', 'qt', 'amount', 'currency', 'year', 'data_source'])

# %%
# df = pd.DataFrame(data=data, columns=my_columns)
df = pd.DataFrame(data)
df.head(100)
# Out:
#         code parent_category  \
# 0   40030000              40
# 1   40040000              40
# 2   40040000              40
# 3   40051000              40
# 4   40052000              40
# ..       ...             ...
# 95  40092200              40
# 96  40092200              40
# 97  40092200              40
# 98  40093100              40
# 99  40093100              40
#
#                                             commodity imported_from unit  \
# 0                    Reclaimed rubber in primary form         China  Kg.
# 1                           Waste and scrap of rubber         China  Kg.
# 2                           Waste and scrap of rubber         India  Kg.
# 3        Rubber compounded wih carbon black or silica         India  Kg.
# 4          Solution, disperision of compounded rubber         India  Kg.
# ..                                                ...           ...  ...
# 95  Tubes, pipes and hoses reinforced or otherwise...  Korea, North  Kg.
# 96  Tubes, pipes and hoses reinforced or otherwise...        Sweden  Kg.
# 97  Tubes, pipes and hoses reinforced or otherwise...   Philippines  Kg.
# 98  Tubes, pipes and hoses, of vulcanised rubber, ...      Malaysia  Kg.
# 99  Tubes, pipes and hoses, of vulcanised rubber, ...         India  Kg.
#
#          qt     amount currency       year                       data_source
# 0   16721.0  2373262.0      NPR  2071/2072  https://nepaltradeportal.gov.np/
# 1   28501.0  2077227.0      NPR  2071/2072  https://nepaltradeportal.gov.np/
# 2   31094.0  1360511.0      NPR  2071/2072  https://nepaltradeportal.gov.np/
# 3   28266.0  5425026.0      NPR  2071/2072  https://nepaltradeportal.gov.np/
# 4    3870.0   593212.0      NPR  2071/2072  https://nepaltradeportal.gov.np/
# ..      ...        ...      ...        ...                               ...
# 95      8.0    16692.0      NPR  2071/2072  https://nepaltradeportal.gov.np/
# 96      1.0     3653.0      NPR  2071/2072  https://nepaltradeportal.gov.np/
# 97      1.0     2276.0      NPR  2071/2072  https://nepaltradeportal.gov.np/
# 98   9197.0  2139590.0      NPR  2071/2072  https://nepaltradeportal.gov.np/
# 99   4586.0   994428.0      NPR  2071/2072  https://nepaltradeportal.gov.np/
#
# [100 rows x 10 columns]
